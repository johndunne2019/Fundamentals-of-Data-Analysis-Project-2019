# %% [markdown]
# # Fundamentals of Data Analysis 2019

# %% [markdown]
# ## Analysis of the Tips data set

# %% [markdown]
# ##  Author John Dunne G00273895

# %% [markdown]
# ![dollar.png](https://www.gannett-cdn.com/-mm-/c3e874beefc535b36fc93a3b3440eb23790ac4e4/c=0-614-1410-1411/local/-/media/2015/06/12/USATODAY/USATODAY/635697214587985559-ThinkstockPhotos-76755037.jpg?width=3200&height=1680&fit=crop)
#
# Image Sourced from: https://www.gannett-cdn.com/-mm-/c3e874beefc535b36fc93a3b3440eb23790ac4e4/c=0-614-1410-1411/local/-/media/2015/06/12/USATODAY/USATODAY/635697214587985559-ThinkstockPhotos-76755037.jpg?width=3200&height=1680&fit=crop

# %% [markdown]
# ##  About this Project
#
# This project concerns the well known tips dataset and the Python packages Seaborn and jupyter. In completing this project I will download the tips dataset and use the Python packages Seaborn and jupyter to perform some analysis on the dataset in order to explain the dataset in detail. I will also endeavour to analyse whether there is a relationship between the total bill and tip amount and anlsyse the relationship between the variables in the data set.

# %% [markdown]
# **Full instructions on how to download and run this jupyter notebook are contained in the Readme file in my repository: https://github.com/johndunne2019/Fundamentals-of-Data-Analysis-Project-2019**

# %% [markdown]
# ## Plan for completing this Project
# **I will break the assessment into 3 sections of work containing subsections:**
#
# **1. Description:**
# * Create a git repository and make it available online.
# * Within the git repository create a jupyter notebook.
# * Download the Tips Data set and within the jupyter notebook use some descriptive analysis on the data set.
# * Try to use the Seaborn and pandas packages to describe the data set.
#
# **2. Regression:**
# * Add a section to the jupyter notebook that discusses and analyses whether there is a relationship between total bill and tip amount.
#
# **3. Analyse:**
# * Analyse the relationship between the variables in the Tips data set.

# %% [markdown]
# ### Table of Contents
#
# * Section 0: Introduction to the Tips data set
# * Section 1: Descriptive Statistics and Plots to describe the Tips data set
#     * Section 1.1: pandas to describe and analyse the Tips data set
#     * Section 1.2: Seaborn to visualise the Tips data set
# * Section 2: Regression
#     * Section 2.1: Introduction to Regression
#     * Section 2.2: Seaborn Linear Regression
#     * Section 2.3: Simple linear regression - best fit line
#     * Section 2.4: Scikit learn to analyse the linear relationship between total bill and tip amount
# * Section 3: Relationship between the variables in the Tips data set
#     * Section 3.1: Seaborn.pairplot
#     * Section 2.2: Seaborn.catplot
#     * Section 3.3: pandas and seaborn to analyse relationship between variables in the data set
# * Section 4: Conclusion

# %% [markdown]
# ## Section 0 - Introduction to the Tips data set
#
# The tips dataset can be viewed at this link: https://github.com/mwaskom/seaborn-data/blob/master/tips.csv which is saved in this repository: https://github.com/mwaskom/seaborn-data.
#
# I have saved the Tips data set in my repository at this link: https://github.com/johndunne2019/Fundamentals-of-Data-Analysis-Project-2019/blob/master/Tips.csv
#
# I found the below explanation on the background and contents of the Tips data set online:
#
# _"In one restaurant, a food server recorded the following data on all customers they served during an interval of two and a half months in early 1990. The restaurant, located in a suburban shopping mall, was part of a national chain and served a varied menu. In observance of local law, the restaurant offered to seat in a non-smoking section to patrons who requested it. Each record includes a day and time, and taken together, they show the server’s work schedule."_
# _
#
# Quote taken from: https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset

# %% [markdown]
# ###  What data is captured in the Tips dataset?
#
# The following is a breakdown of the data that is captured in the Tips dataset:
# * There are 244 rows and 7 columns of data in the Tips data set.
# * The first column is called total_bill and this is the total amount of each bill in US dollars.
# * The second column is called tip and is the amount of the tip (gratuity) given by each party in US dollars.
# * The third column is the sex of the person paying for the bill.
# * The fourth column records if there was a smoker among the party ie- if the party sat in the smoking or non smoking section of the restaurant.
# * The fifth column of data shows the day of the week.
# * The sixth column of data shows the time of day- dinner or lunch.
# * The seventh and final column records the size of the party.

# %% [markdown]
# **Tips Data set References**
# * Repository from which seaborn.load reads the data set from: https://github.com/mwaskom/seaborn-data
# * Direct link to the data set csv file: https://github.com/mwaskom/seaborn-data/blob/master/tips.csv
# * Seaborn.load https://stackoverflow.com/questions/30336324/seaborn-load-dataset
# * Background of the Tips dataset: https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset

# %% [markdown]
# ##  Section 1 : Descriptive Statistics and Plots to describe the Tips data set
#
# **This is the first section of my work and in this section I will conduct analyses on the Tips data set using descriptive statistics and plots.**
#
# The Python packages I will use to perform some analysis on the data set are:
#
# * **pandas**
#
# I will read in the data set with pandas and return some descriptive statistics about the data set using some functions within the pandas library.
#
# * **Seaborn**
#
# I will use Seaborn to read in the data set and output some plots based on the data set and I will try to explain how the different types of plots work and why they would be used in analysing a data set.

# %% [markdown]
# ### Import the Python packages I will use in this jupyter notebook:

# %%
# %matplotlib inline
# This command makes matplotlib show the interactive plots in this notebook
import numpy as np
# numpy imported and given the shortened name np
import pandas as pd
# pandas imported and given the shortened name pd
import matplotlib.pyplot as plt
# matplotlib pyplot imported and given the shortened name plt
import seaborn as sns
# seaborn imported and given the shortened name sns
sns.set(style="darkgrid")
# Sourced this line from the Seaborn tutorial here: http://seaborn.pydata.org/tutorial/relational.html
# This command is used to set the background style for the grids in the plots that will be created using the Seaborn package

# %% [markdown]
# ### Section 1.1 - pandas to describe and analyse the Tips data set
# pandas or Python Data Analysis Library is a Python package than can be used to analyse data sets such as the Tips data set. I will use pandas in this section to do some basic descriptive statistics on the Tips data set. I will also add a short description about each function that I use and how and why they would be useful in analysing a data set.
#
# **pandas can deal with both strings and floating point numbers and so is a good package to use to analyse the Tips data set**
#
# **Some useful links:**
# * pandas documentation: https://pandas.pydata.org/
# * 10 minutes to pandas: https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
# * Wes McKinney - 10-minute tour of pandas - https://www.youtube.com/watch?v=_T8LGqJtuGc

# %% [markdown]
# #### **Reading in the data set**
# **pandas.read_csv**
#
# pandas.read_csv documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# pandas.read_csv is used to read comma separated value files into a dataframe.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/johndunne2019/Fundamentals-of-Data-Analysis-Project-2019/master/Tips.csv")
# pandas.read_csv function used to read in the Tips data set from my repository
# Has to be the url to the the raw version of the data set in order for pandas to read the csv file in
# df - dataframe
df
# the data frame is shown below - 244 rowns and 7 columns
# pandas.read_csv documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# I can see from the above there are 244 rows and 7 columns of data in the Tips data set

# %% [markdown]
# #### **Descriptive Statistics**
# Now that the data set has been read in by pandas I will use descriptive statistics to look at the data set in more detail

# %% [markdown]
# ##### Dataframe.head()
#
# Dataframe.head() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html
#
# Dataframe.head() is used to return thr first rows of a data set. The default is 5 if no parameter is entered.

# %%
print("Dataframe.head() used to print the first 5 rows of data by default")
df.head()
# the dataframe.head() function is used to show the first 5 rows of data
# The user can add an argument in the brackets to have more or less than 5 rows displayed
# Dataframe.head documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html
# Out:
# Dataframe.head() used to print the first 5 rows of data by default
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### Dataframe.tail()
#
# Dataframe.tail() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html
#
# Dataframe.tail() is used to return the last rows of a dataset, the default is 5 is no parameter is given.

# %%
print("Dataframe.tail() used to print the last 8 rows of data")
df.tail(8)
# the dataframe.tail() function is used to view in this case the last 8 rows of data in the data set
# Dataframe.tail documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html
# Out:
# Dataframe.tail() used to print the last 8 rows of data
#      total_bill   tip     sex smoker   day    time  size
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ##### Dataframe.info()
#
# Dataframe.info() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html
#
# _"Print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage."_
#
# Source: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html

# %%
df.info()
# df.info() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# ##### Dataframe.shape()
#
# Dataframe.shape documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html
#
# Dataframe.shape returns a table that shows the number of rows and columns in a dataframe.

# %%
print("The number of rows and columns of data are printed to the screen below:")
df.shape
# The number of rows and columns of data is retruned using the dataframe.shape function
# Dataframe.shape documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html
# Out:
# The number of rows and columns of data are printed to the screen below:
# (244, 7)

# %% [markdown]
# ##### Display only total_bill and tip amounts

# %%
print("Only total bill and tip amount is shown")
df[['total_bill', 'tip']]
# Out:
# Only total bill and tip amount is shown
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# 5         25.29  4.71
# 6          8.77  2.00
# 7         26.88  3.12
# 8         15.04  1.96
# 9         14.78  3.23
# 10        10.27  1.71
# 11        35.26  5.00
# 12        15.42  1.57
# 13        18.43  3.00
# 14        14.83  3.02
# 15        21.58  3.92
# 16        10.33  1.67
# 17        16.29  3.71
# 18        16.97  3.50
# 19        20.65  3.35
# 20        17.92  4.08
# 21        20.29  2.75
# 22        15.77  2.23
# 23        39.42  7.58
# 24        19.82  3.18
# 25        17.81  2.34
# 26        13.37  2.00
# 27        12.69  2.00
# 28        21.70  4.30
# 29        19.65  3.00
# ..          ...   ...
# 214       28.17  6.50
# 215       12.90  1.10
# 216       28.15  3.00
# 217       11.59  1.50
# 218        7.74  1.44
# 219       30.14  3.09
# 220       12.16  2.20
# ...

# %% [markdown]
# ##### Datafram.sum()
#
# Dataframe.sum: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html
#
# Dataframe.sum returns the sum value of all values requested.

# %%
print("The sum of all bills in the data set in dollars:")
print(df.total_bill.sum().astype(int))
print("The sum of all tips in the data set in dollars:")
print(df.tip.sum().astype(int))
# pandas dataframe.sum: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html
# .astype(int) used to retrun an integer for output
# Out:
# The sum of all bills in the data set in dollars:
# 4827
# The sum of all tips in the data set in dollars:
# 731

# %% [markdown]
# ##### Dataframe.describe()
#
# Dataframe.describe documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
#
# _"Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values."_
#
# Source:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html

# %%
print("Dataframe.describe prints a description of the 3 columns of data containing floats below")
df.describe()
# Dataframe.describe is used to give an overview of the Tips data set
# Dataframe.describe documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
# Out:
# Dataframe.describe prints a description of the 3 columns of data containing floats below
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# We can see above the results are returned on the 3 columns of data containing floating point numbers.
#
# **A summary of the findings:**
# * count - There are 244 rows of data in each of the 3 columns analysed.
# * mean -The mean bill was 19.79 with the mean tip of 3.00 while the mean party size was 2.57 people.
# * std - The standard deviation - we can see there is a deviation of 8.90 from the mean in total bill for example.
# * min - The smallest bill was 3.07 with the smallest tip of 1.00
# * max - The higest bill was 50.81 and the highest tip 10.00 with the largest party size being 6 people

# %% [markdown]
# **Output of pandas.dataframe.describe() explained:**
# * count = total number of rows of data in the data set.
# * mean = the central tendency of the data.
# * std = standard deviation which is a measurement of the variance of each data point relative to the mean.
# * min = the smallest figure collected in each column of data.
# * 25% = the 25th percentile - meaning 25% of the total count of measurements collected fall below this measurement.
# * 50% = the 50th or median percentile meaning this is the central collected in each column, half of the data collected falls below this measurement and half is above this measurement. Further details on how percentile is calculated can be read here: https://www.statisticshowto.datasciencecentral.com/probability-and-statistics/percentiles-rank-range/.
# * 75% = the 75th percentile - meaning 75% of the total count of measurements collected fall below this measurement and 25% are above this measurement.
# * max = the largest measurement collected kin each column of data.

# %% [markdown]
# #### Slicing the data set

# %%
df[["time", "day"]][3:8]
# Columns of data can be called by name in pandas 
# User can add argument to select only certain rows of data
# Taken from example covered in lectures: 
# https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/pandas-with-iris.ipynb
# Out:
#      time  day
# 3  Dinner  Sun
# 4  Dinner  Sun
# 5  Dinner  Sun
# 6  Dinner  Sun
# 7  Dinner  Sun

# %% [markdown]
# ##### Dataframe.iloc()
#
# Dataframe.iloc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
#
# Dataframe.iloc() can be used to call values from a data frame by their integer position in the dataframe.

# %%
df.iloc[7]
# Dataframe.iloc used to display the column with index 7 
# Dataframe.iloc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
# Out:
# total_bill     26.88
# tip             3.12
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 7, dtype: object

# %% [markdown]
# ##### Boolean Selects - Dataframe.loc()
#
# A boolean select is statement that returns a true or false answer. In the below example true will be returned for all sex values that are male and false for all female sex values.
#
# Dataframe.loc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
#
# Dataframe.loc() can be used to call values from a dataframe using the label name or a boolean array.

# %%
df.loc[:, 'sex'] == 'Male'
# the loc function can be used to identify rows where a condition is true or false
# Taken from example covered in lecture:
# https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/pandas-with-iris.ipynb
# Dataframe.loc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11     False
# 12      True
# 13      True
# 14     False
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20      True
# 21     False
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29     False
#        ...
# 214    False
# 215    False
# 216     True
# 217     True
# 218     True
# 219    False
# 220     True
# 221    False
# 222     True
# 223    False
# 224     True
# 225    False
# 226    False
# 227     True
# 228     True
# 229    False
# 230     True
# 231     True
# 232     True
# 233     True
# 234     True
# 235     True
# 236     True
# 237     True
# 238    False
# 239     True
# 240    False
# 241     True
# 242     True
# 243    False
# Name: sex, Length: 244, dtype: bool

# %% [markdown]
# ##### Dataframe.mean()
#
# Dataframe.mean documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
#
# Dataframe.mean() is used to return the mean values of the requested data within the dataframe.

# %%
print("dataframe.mean() is used to display the mean bill amount, tip amlount and party size")
df.mean()
# Dataframe.mean documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
# Out:
# dataframe.mean() is used to display the mean bill amount, tip amlount and party size
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# ##### **Dataframe.astype() to return an integer value**
#
# Dataframe.astype documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html

# %%
print(".astype used to display as an integer")
df.mean().astype(int)
# Out:
# .astype used to display as an integer
# total_bill    19
# tip            2
# size           2
# dtype: int32

# %% [markdown]
# ##### Dataframe.std()
#
# Dataframe.std() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html
#
# Dataframe.std() returns the sample standard deviation of the requested sample within the dataframe. Standard deviation between the variance or dispersal of values within the data set.

# %%
print("dataframe.std() can be used to display the standard deviation of each column of data")
df.std()
# Out:
# dataframe.std() can be used to display the standard deviation of each column of data
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
print(".astype used to display as an integer")
df.std().astype(int)
# Out:
# .astype used to display as an integer
# total_bill    8
# tip           1
# size          0
# dtype: int32

# %% [markdown]
# #### Grouping the data set by variable

# %% [markdown]
# ##### **DataFrame.groupby**
#
# pandas.dataframe.groupby documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
#
# _"A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups."_

# %% [markdown]
# ##### **Dataframe.groupby.count()**
#
# Dataframe.groupby.count() could be used to see how many entries are recorded in the data set grouping by a particular variable.

# %% [markdown]
# **Sex:**

# %%
df.groupby('sex').count()
# I read about using pandas.groupby in this tutorial: https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# pandas.groupby documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %% [markdown]
# pandas.groupby shows there are 87 males and 157 female values in the data set.

# %% [markdown]
# **Smoker:**

# %%
df.groupby('smoker').count()
# Out:
#         total_bill  tip  sex  day  time  size
# smoker
# No             151  151  151  151   151   151
# Yes             93   93   93   93    93    93

# %% [markdown]
# There are 151 non smokers and 93 smokers

# %% [markdown]
# **Day:**

# %%
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %% [markdown]
# * Thursday - 19 tables
# * Friday - 87 tables
# * Saturday - 76 tables
# * Sunday - 62 tables

# %% [markdown]
# **Time:**

# %%
df.groupby('time').count()
# Out:
#         total_bill  tip  sex  smoker  day  size
# time
# Dinner         176  176  176     176  176   176
# Lunch           68   68   68      68   68    68

# %% [markdown]
# 176 tables at dinner and 68 at lunch

# %% [markdown]
# **Day and time:**

# %%
df.groupby(['day','time']).count()
# Out:
#              total_bill  tip  sex  smoker  size
# day  time
# Fri  Dinner          12   12   12      12    12
#      Lunch            7    7    7       7     7
# Sat  Dinner          87   87   87      87    87
# Sun  Dinner          76   76   76      76    76
# Thur Dinner           1    1    1       1     1
#      Lunch           61   61   61      61    61

# %% [markdown]
# **Party size:**

# %%
df.groupby('size').count()
# Out:
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4

# %% [markdown]
# * 1 - 4 tables
# * 2 - 156 tables
# * 3 - 38 tables
# * 4 - 37 tables
# * 5 - 5 tables
# * 6 - 4 tables

# %% [markdown]
# **Section 1.1 References**
# * pandas.read_csv documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
# * Blog post on reading in csv files with pandas: https://www.shanelynn.ie/python-pandas-read_csv-load-data-from-csv-files/
# * Dataframe.head documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html
# * Dataframe.tail documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html
# * Dataframe.describe(): https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html
# * Percentile: https://www.statisticshowto.datasciencecentral.com/probability-and-statistics/percentiles-rank-range/
# * Dataframe.shape documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html
# * jupyter notebook pandas descriptive statistics example covered in lecture: https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/pandas-with-iris.ipynb
# * Dataframe.loc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
# * Dataframe.iloc documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
# * Dataframe.mean documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html
# * Dataframe.std() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html
# * pandas.DataFrame.groupby: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
# * pandas groupby: https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/
# * astype(int): https://stackoverflow.com/questions/45451189/in-pandas-can-you-aggregate-by-mean-and-round-that-mean-to-the-nearest-int
# * pandas sum: https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# * Dataframe.sum(): https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html
# * pandas.groupby in action: https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# * Blog post: https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
# * Dataframe.round(): https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.round.html
# * df.info() documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html
# * Dataframe.astype documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html

# %% [markdown]
# ### Section 1.2 - Seaborn to visualise the Tips data set
#
# Seaborn is a data visualization package within Python which is based on matplotlib. Seaborn can be used to make statistical graphics in Python.
#
# The official Seaborn documentation is here: https://seaborn.pydata.org/index.html and the official Seaborn tutorial is here: https://seaborn.pydata.org/index.html.
#
# _"Seaborn aims to make visualization a central part of exploring and understanding data. Its dataset-oriented plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots."_
#
# Sourced from the official Seaborn documentation - https://seaborn.pydata.org/introduction.html
#
# **Some useful links:**
# * The official Seaborn tutorial: https://seaborn.pydata.org/tutorial.html
# * Seaborn documentation: https://seaborn.pydata.org/index.html
# * Youtube: https://www.youtube.com/watch?v=TLdXM0A7SR8

# %% [markdown]
# #### Seaborn.load_dataset to load in the Tips data set
# The Seaborn.load_dataset is one way in which a user can read in a data set that is already built into the Seaborn package. This works in the case of the Tips dataset as the Tips dataset is be default loaded in the Seaborn package.
#
# Seaborn.load_dataset documentation: https://seaborn.pydata.org/generated/seaborn.load_dataset.html
#
# _"Load a dataset from the online repository (requires internet)."_
#
# Some further reading on loading in data set: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial#load
#
# Another way Seaborn can read the data set is from a pandas data frame. I will use both methods in my descriptive analysis.
#
# **I waill load in the Tips data set using Seaborn.load_dataset:**

# %%
tips = sns.load_dataset("tips")
# Seaborn.load_dataset command used to load the Tips data set that comes built into the Seaborn package
# the variable tips is set equal to the built in tips data set

# %% [markdown]
# #### Seaborn.relplot to show the Tips data set in some more detail
# A relplot in seaborn is used to show the relationship between two variables, and also allows the mapping of subsets. In this section I will examine the relationship between total bill and tip amount and also try to add some subsets of other variables from the Tips data set.
#
# The Seaborn.relplot documentation: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
#
# _"This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets. The kind parameter selects the underlying axes-level function to use:"_
#
# From: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot

# %% [markdown]
# #### Plotting 2 variables on a relplot

# %% [markdown]
# **I will use seaborn.relplot to plot total bill and total tip amounts:**

# %%
sns.relplot(x="total_bill", y="tip", data=tips);
# seaborn.relplot takes the arguments x and y to plot on the x and y axis
# data is set to the variable tips which was earlier set to be the built in tips data set

# %% [markdown]
# #### Adding Subsets to the relplot
#
# **Seaborn.relplot takes "hue", "style" and "size" arguments:**
#
# _"The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters. These parameters control what visual semantics are used to identify the different subsets. It is possible to show up to three dimensions independently by using all three semantic types, but this style of plot can be hard to interpret and is often ineffective."_
#
# From: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
#
# * hue - differentiation is made by the colour of the points on the plot
# * style - differentiation is made by the style of the points on the plot
# * size - differentiation is made by the size of the points on the plot

# %% [markdown]
# **The "hue" parameter colours the x and y variables that are plotted according to a third named variable from the data set. I have given an example below using the column of data sex as the hue:**
#
# _"Grouping variable that will produce elements with different colors. Can be either categorical or numeric, although color mapping will behave differently in latter case."_
#
# From the seaborn.relplot documentation: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", data=tips);
# I have added the hue argument and set it to the variable sex from the data set
# As we can see in the plot below male and female ahve been given 2 different colours

# %% [markdown]
# **The "style" parameter adds another variable to the plot and the differentiation is shown by the style of the points plotted**
#
# _"Grouping variable that will produce elements with different styles. Can have a numeric dtype but will always be treated as categorical."_
#
# From the seaborn.relplot documentation: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
#
# In the example below both sex and time variables have been used to draw subsets of the main plot of total bill and tip amount. Sex is shown using the hue argument which has coloured male and female on the plot. Time is shown using the style argument which has used an x for dinner and a dot for lunch. Looking at the plot below I can see for example, a bluedot corresponds to the total bill and tip amount given by a male at lunch time.

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", style="time", data=tips);
# I have added the style parameter and set it to show the data from the time variable in the data set
# As before male and female are plotted in 2 different colours
# Now the time variable is also shown on the plot with an x for dinner and a dot for lunch

# %% [markdown]
# **The "size" parameter can be used to introduce a third sub set to the plot with the size of the point being used to differentiate between variables**
#
# _"Grouping variable that will produce elements with different sizes. Can be either categorical or numeric, although size mapping will behave differently in latter case."_
#
# From seaborn.relplot documentation: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
#
# In the example I have shown below there are 3 subsets of the Tips dataset shown on the plot. I have used all 3 arguments- "hue", "size" and "style" to create 3 subsets of the total bill and tip amount. Looking at the plot below I can see that a large blue dot would correspond to a total bill and tip amount given by a male smoker at lunch time. I can also see that a small orange x would correspond to the total bill and tip amount given by a female non smoker at dinner.

# %%
sns.relplot(x="total_bill", y="tip", hue="sex", style="time", size="smoker", data=tips);
# I have added the parameter size and set equal to the smoker data from the Tips dataset
# Now there are 3 subsets of the data set shown on the plot
# sex - colour
# time - style
# smoker - size

# %% [markdown]
# #### Seaborn.relplot - "Kind"
#
# **Seaborn.relplot takes a "kind" argument which can be used to change from the default scatter plot to a line plot**
#
# The documentation for scatterplot and line plot in Seaborn can be found at the below links:
# * Seaborn.scatterplot: https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot
# * Seaborn.lineplot: https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot

# %%
sns.relplot(x="total_bill", y="tip", kind="line", data=tips);
# Thr kind argument is used to change the default scatter plot to a line plot
# Out:
# C:\Users\John\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Seaborn.displot
# The seaborn.distplot documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html
#
# Within Seaborn the distplot function plots a histogram of the data. This is a univariate distribution.
#
# _"A distplot plots a univariate distribution of observations. The distplot() function combines the matplotlib hist function with the seaborn kdeplot() and rugplot() functions."_
#
# From: https://pythonbasics.org/seaborn-distplot/

# %% [markdown]
# **Seaborn.distplot showing total_bill:**

# %%
sns.distplot(tips['total_bill'], hist=True)
# seaborn.distplot to plot total_bill
# the hist argument is set to true to plot a histogram and false to have no histogram plotted

# %% [markdown]
# **The same plot is shown below with the parameter - hist=false:**

# %%
sns.distplot(tips['total_bill'], hist=False)
# I have set hist=False to have just the curve

# %% [markdown]
# #### Seaborn.distplot takes the bins argument:
# **Seaborn.distplot to show tip amount:**

# %%
sns.distplot(tips['tip'], bins=40)
# seaborn.distplot takes a bins argument to set bin size
# I have asked for 40 bins in this case

# %% [markdown]
# #### Changing the figure size with seaborn.distplot

# %%
sns.set(rc={"figure.figsize": (8, 4)});
# I took this line from the blog post here: https://pythonbasics.org/seaborn-distplot/
sns.distplot(tips['tip'], bins=40)

# %% [markdown]
# **Findings:**
# * The majority of bill amounts fall between 10 and 25 dollars.
# * There is a large spike in tip amount of approx 2 dollars.
# * The majority of tips fall into the range between 1.50 and 4 dollars with some outliers between 6 and 10 dollars.

# %% [markdown]
# #### Seaborn.countplot
#
# The seaborn.countplot documentation: https://seaborn.pydata.org/generated/seaborn.countplot.html
#
# _"Show the counts of observations in each categorical bin using bars."_
#
# _"A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable. The basic API and options are identical to those for barplot(), so you can compare counts across nested variables."_

# %% [markdown]
# ##### **Countplot - Day:**

# %%
sns.countplot(x="day", data=tips)
# countplot used to show the number of parties dining in the restauarnt each day

# %% [markdown]
# **I can verify the numbers shown in the plot above by using pandas.groupby.count() to show the numbers of parties dining in the restaurant by day:**

# %%
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %% [markdown]
# **Seaborn.countplot takes the argument "hue":**
#
# The "hue" argument can be used to introduce a third variable to the plot which is distinguished by colour.

# %% [markdown]
# ##### **Countplot - Day and smoker:**

# %%
sns.countplot(x="day", hue= "smoker", data=tips)

# %% [markdown]
# **Again I can verify that the numbers shown in the plot using pandas.groupby:**

# %%
df.groupby(['day','smoker']).count().round(2)
# Out:
#              total_bill  tip  sex  time  size
# day  smoker
# Fri  No               4    4    4     4     4
#      Yes             15   15   15    15    15
# Sat  No              45   45   45    45    45
#      Yes             42   42   42    42    42
# Sun  No              57   57   57    57    57
#      Yes             19   19   19    19    19
# Thur No              45   45   45    45    45
#      Yes             17   17   17    17    17

# %% [markdown]
# ##### **Countplot - Day and sex:**

# %%
sns.countplot(x="day", hue= "sex", data=tips)

# %%
df.groupby(['day','sex']).count().round(2)
# Out:
#              total_bill  tip  smoker  time  size
# day  sex
# Fri  Female           9    9       9     9     9
#      Male            10   10      10    10    10
# Sat  Female          28   28      28    28    28
#      Male            59   59      59    59    59
# Sun  Female          18   18      18    18    18
#      Male            58   58      58    58    58
# Thur Female          32   32      32    32    32
#      Male            30   30      30    30    30

# %% [markdown]
# ##### **Countplot on Y axis - Day and smoker:**
# The y axis can be used instead of the x axis to plot from the data set:

# %%
sns.countplot(y="day", hue= "smoker", data=tips)

# %% [markdown]
# **Findings:**
# * There were more parties seated in the non smoking sections on all days except Friday.
# * There were more females paying the bill on Thursday but more males on all of the other 3 days.
# * Friday was extremely quiet day and Saturday and Sunday were by far the busiest days in the restaurant.
# * These countplots might be of interest to a waiter interested in analysing trends relating to what are the busiest days in the restauarnt and which area may be more busy smoking or non smoking.

# %% [markdown]
# **Section 1.2 References**
# * Seaborn tutorial: https://seaborn.pydata.org/tutorial.html
# * Seaborn documentation: https://seaborn.pydata.org/index.html
# * Youtube: https://www.youtube.com/watch?v=TLdXM0A7SR8
# * Seaborn.load_dataset documentation: https://seaborn.pydata.org/generated/seaborn.load_dataset.html
# * Some further reading on loading in data set: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial#load
# * Seaborn.relplot documentation: https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot
# * Plotting in Seaborn: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial#load
# * The seaborn.distplot documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html
# * Plotting with distplot: https://pythonbasics.org/seaborn-distplot/
# * The seaborn.countplot documentation: https://seaborn.pydata.org/generated/seaborn.countplot.html

# %% [markdown]
# ## Section 2: Regression

# %% [markdown]
# **In this section I will discuss and analyse whether there is a relationship between the total bill and tip amount.**

# %% [markdown]
# ### 2.1: Introduction to Regression
#
# _"Regression analysis is a powerful statistical method that allows you to examine the relationship between two or more variables of interest."_
#
# _"While there are many types of regression analysis, at their core they all examine the influence of one or more independent variables on a dependent variable."_
#
# Source: https://www.surveygizmo.com/resources/blog/regression-analysis/
#
# In regression analysis you have a dependent variable and an independent variable:
# * Dependent variable - the variable you are trying to understand or predict
# * Independent variable - the factors that have an affect on the dependent variable
#
# In this case I want to analyse if there is a relationship between total bill and tip amount. So I could say:
# * The dependent variable is - tip
# * The independent variable is - total bill
#
# Before ever doing any regression analysis I would hazard a guess that there is a relationship between total bill and tip amount. I would assume that the higher the total bill amount the higher the tip amount would be.

# %% [markdown]
# **First I will plot the total bill and tip amounts in order to work towards identifying if their is a relationship between total bill and tip amount:**

# %%
sns.relplot(x="total_bill", y="tip", data=tips);
# seaborn.relplot to plot total bill and tip amount

# %% [markdown]
# **From the above plot I can see:**
# * The highest tips seem to come from the highest bill amounts.
# * The lower tips generally seem to correlate to the lower total bill amounts too.
# * There are some exceptions, for example, I can see one tip of approximately 5 dollars for a total bill amount of approximately 8 dollars.

# %% [markdown]
# ### 2.2: Seaborn Linear Regression
# **To see more clearly the relationship between total bill and tip amount I will draw a line through the data, known as the regression line.**
#
# _"The regression line represents the relationship between your independent variable and your dependent variable. "_
#
# From: https://www.surveygizmo.com/resources/blog/regression-analysis/
#
# The goal of linear regression could be to make a prediction of what value we could expect to see in one variable based on the value of another variable. So in this example I could predict what the tip amount would likely by based on a total bill amount that wasnt measured in the data set.
#
# **The Regression line is represented in the below equation:**
#
# ![regression.png](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-41f1da8f1b6e63d6b8ab96507bc7d397_l3.svg)
#
# Image from: https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-41f1da8f1b6e63d6b8ab96507bc7d397_l3.svg
#
# **Seaborn Regression Plots**
#
# Seaborn allows the user to plot linear relationships.
#
# _"The regression plots in seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses. Regression plots as the name suggests creates a regression line between 2 parameters and helps to visualize their linear relationships."_
#
# Source: https://www.geeksforgeeks.org/seaborn-regression-plots/
#
# #### There are 2 main types of regression plots in Seaborn: regplot and lmplot:
#
# * regplot(): https://seaborn.pydata.org/generated/seaborn.regplot.html#seaborn.regplot
# * lmplot(): https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot
#
# The different between them is explained in the regression section of the Seaborn documentation: https://seaborn.pydata.org/tutorial/regression.html
#
# _"Two main functions in seaborn are used to visualize a linear relationship as determined through regression. These functions, regplot() and lmplot() are closely related, and share much of their core functionality. It is important to understand the ways they differ, however, so that you can quickly choose the correct tool for particular job."_
#
# _"You should note that the resulting plots are identical, except that the figure shapes are different. We will explain why this is shortly. For now, the other main difference to know about is that regplot() accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame object passed to data. In contrast, lmplot() has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” or “tidy” data. Other than this input flexibility, regplot() possesses a subset of lmplot()’s features, so we will demonstrate them using the latter."_
#
# Source: https://seaborn.pydata.org/tutorial/regression.html

# %% [markdown]
# #### Seaborn.lmplot
#
# The lmplot function in Seabon creates a scatterplot with a linear fit on top of it. There are parameters that can be used to display different views and to plot using different variables and I will try to display some below:
#
# Further reading on the functionality withing seaborn.lmplot:
# * Visualizing linear relationships in Seaborn: https://seaborn.pydata.org/tutorial/regression.html
# * Seaborn.lmplot documentation page: https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot
# * Blog post: https://www.geeksforgeeks.org/seaborn-regression-plots/

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
# seaborn.lmplot to plot the linear relationship between total bill and tip amount

# %% [markdown]
# #### Seaborn.regplot():
# Seaborn.regplot is used to plot data with a linear regression model fit.
#
# _" regplot() accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame object passed to data"_
#
# From: https://seaborn.pydata.org/tutorial/regression.html
#
# Further reading on Seaborn.regplot():
# * Visualizing linear relationships in Seaborn: https://seaborn.pydata.org/tutorial/regression.html
# * Seaborn.regplot(): https://seaborn.pydata.org/generated/seaborn.regplot.html
# * Seaborn - Linear relationships: https://www.tutorialspoint.com/seaborn/seaborn_linear_relationships.htm

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# seaborn.regplot(): https://seaborn.pydata.org/generated/seaborn.regplot.html

# %% [markdown]
# **I can see from the above lmplot and regplot:**
# * There is a relationship between total bill and tip amount.
# * The higher the total bill amount the higher the tip amount is.
# * There are a few exceptions where some high bills have smaller tips but generally the higer tip amounts come from higher bills.
# * Looking at the regression line in the plots above we could predict a bill amount of 10 dollars to yield a tip amount of approximately 2 dollars.
# * A bill amount of 50 dollars should yield a tip amount of approx 6 dollars.
# * I will look at some more examples of regression plots now.

# %% [markdown]
# **Seaborn.lmplot takes the hue parameter which plots a third variable:**
#
# Further reading on the documentation page: https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot
#
# **hue = smoker:**

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)
# hue argument entered to add a third variable

# %% [markdown]
# **When the hue parameter is added for smoker/non smoker I can see:**
# * The regression line for non smoker has a higher trajectory as the bill amounts increase.
# * This leads me to believe a non smoker is more likely to give a larger tip amount than a smoker on larger bill amounts.
# * The opposite might be said for lower bill amounts where smokers seem to be more likely to give higher tip amounts than non smokers.

# %% [markdown]
# **"markers" parameter can be added to plot the variables in different styles:**
#
# **hue = sex:**

# %%
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips, markers=["o", "x"])
# hue argument added to plot a third variable
# markers argument can be asded to plot the variavbles in 2 different styles

# %% [markdown]
# **When the hue parameter is added for sex I can see:**
# * The regression lines are quiet similar.
# * Looking at this I dont think sex has a huge influence on the relationship between total bill and tip amount.

# %% [markdown]
# **"col" argument to plot the third variable across different columns:**
#
# Linear relationship between total bill and tip amount separated into smoker and non smoker:

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="smoker", data=tips)
# col argument added to plot 2 variables across different columns
# hue argument can also be used to use 2 different colours

# %% [markdown]
# #### **Section 2.1 and 2.2 References**
# * What is Regression Analysis and Why Should I Use It?: https://www.surveygizmo.com/resources/blog/regression-analysis/
# * A refresher on regression analysis: https://hbr.org/2015/11/a-refresher-on-regression-analysis
# * Simple Linear Regression with NumPy- https://github.com/ianmcloughlin/jupyter-teaching-notebooks/raw/master/simple-linear-regression.ipynb
# * Linear regression in Python: https://realpython.com/linear-regression-in-python/#regression
# * Seaborn regression plots: https://www.geeksforgeeks.org/seaborn-regression-plots/
# * Seaborn visualising linear relationships: https://seaborn.pydata.org/tutorial/regression.html
# * Seaborn.lmplot: https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot
# * Seaborn.regplot(): https://seaborn.pydata.org/generated/seaborn.regplot.html#seaborn.regplot

# %% [markdown]
# ### 2.3: Simple linear regression - best fit line
# After viewing the series of lecture videos on simple linear regression I will to find the slope and y intercept values for the best fit line.
#
# Each line has a cost and there is a formula that is used to calculate this cost:
#
# **∑i(yi−mxi−c)2**
#
# When looking for the best fit line we are looking for the line with the minimum cost. There is also a formula used to calculate this:
#
# **Cost(m,c)=∑i(yi−mxi−c)2**
#
# In summary in order to calculate the result of the above formula we need to follow the steps below:
# * Calculate the mean of the x values and subtract the mean from the actual x values.
# * Calculate the mean of the y values and subtract the mean from the actual y values.
# * The new x values after the above calculation are multiplied by the resulting y values after the above calculation and and divided by the x results multiplied by the x results.
# * This gives the m value or slope of the line.
# * The m value is then used to fine the c value which is the y intercept.
# * This is done by subtracting the slope from the mean y value and multiplying by the mean x value.
#
# I wrote the below code using the examples we covered in the lecture series on simple linear regression as a starting point. The lecture is captured in a jupyter ntebook here: https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/simple-linear-regression.ipynb

# %%
# The mean values are calculated using numpy.mean
bill_mean = np.mean(tips['total_bill'])
tip_mean = np.mean(tips['tip'])

# The mean values are subtracted from the actual values from the data set
bill = tips['total_bill'] - bill_mean
tip = tips['tip'] - tip_mean

# The best m is found by the following calculation which we looked at in lecture video
m = np.sum(bill * tip) / np.sum(bill * bill)
# The m value found above is used to calculate the best c 
c = tip_mean - m * bill_mean

print("m is %8.6f and c is %6.6f." % (m, c))
# I sourced this line from the notebook we looked at in the lectures:
# https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/simple-linear-regression.ipynb
# Out:
# m is 0.105025 and c is 0.920270.

# %% [markdown]
# **numpy.polyfit to calculate the m and c values:**
#
# numpy.polyfit can be used to give the same result as the calculation above.
#
# numpy.polyfit documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html.
#
# The numpy.polyfit function takes 3 parameters, an x value, a y value and degree which is the line the user is looking to fit. As I saw in the lecture the degress parameter should be set to 1 for a linear model fit.

# %%
print("The slope (m) and y intercept values (c) are:")
print(np.polyfit(tips['total_bill'], tips['tip'], 1))
# numpy.polyfit used to get the slope and y intercept values of the best fit line
# setting the parameter 1 for a linear model fit
# Out:
# The slope (m) and y intercept values (c) are:
# [0.10502452 0.92026961]

# %% [markdown]
# **Now I will try to plot the best fit line:**

# %%
plt.plot(tips['total_bill'],  tips['tip'], 'r.', label='Actual data')
# the actual bill and tip amounts from the data set are plotted in red dots with the label 'Actual data'
plt.plot(tips['total_bill'], 0.10502452 * tips['total_bill'] + 0.92026961, 'b-', label='Best fit line')
# the best fit line is plotted using the formula we looked at in the lecture video
plt.xlabel('Total_bill')
plt.ylabel('Tips')
# labels given to x and y labels
plt.legend()
# legend will be displayed in the plot
plt.show()
# plt.show() to show the plot

# %% [markdown]
# **numpy.corrcoef**
#
# numpy.corrcoef is used to return the coefficient of determination also known as the Pearson product-moment correlation coefficients. This is a measure of the linear correlation betwee the x and y variables or in other words how much the variance of y is determined by x. There may be other factors apart from the value of x that have an impact on the value of y and this is why we would do this calculation.
#
# The calculation is shown below:
#
# ![corr.png](https://docs.scipy.org/doc/numpy/_images/math/c4bf86d659e6d2625eb24b84c2389123042f9262.svg)
#
# _"Correlation values range between -1 and 1.There are two key components of a correlation value:"_
#
# _" magnitude – The larger the magnitude (closer to 1 or -1), the stronger the correlation"_
#
# _" sign – If negative, there is an inverse correlation. If positive, there is a regular correlation."_
#
# Source: http://benalexkeen.com/correlation-in-python/

# %%
np.corrcoef(tips['total_bill'], tips['tip'])
# used numpy.corrcoef to calculate the R-squared value 
# the x and y parameters are entered as total bill and tip amounts in order to see the relationshio between them
# Out:
# array([[1.        , 0.67573411],
#        [0.67573411, 1.        ]])

# %% [markdown]
# **Looking at the result the correlation between total_bill and tip amount is positive 0.67573411.**
#
# This is a positive correlation and is reasonably strong. So there is a relationship between total bill and tip amount in that the higher the bill amount the higher the tip amount will be. However, the relationship is not perfectly linear. A perfectly linear relationship would have coefficients of positive 1.

# %% [markdown]
# **The R-Squared value:**

# %% [markdown]
# _"R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression."_
#
# _"R-squared is always between 0 and 100%:"_
#
# _"0% indicates that the model explains none of the variability of the response data around its mean."_
#
# _"100% indicates that the model explains all the variability of the response data around its mean."_
#
# Source: https://blog.minitab.com/blog/adventures-in-statistics-2/regression-analysis-how-do-i-interpret-r-squared-and-assess-the-goodness-of-fit

# %%
print ("The R-squared value is:")
print(np.corrcoef(tips['total_bill'], tips['tip'])[0][1]**2)
# Sourced this line from the notebook used in lectures:
# https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/simple-linear-regression.ipynb
# Out:
# The R-squared value is:
# 0.45661658635167635

# %% [markdown]
# **Looking at the result 45.6% of the data is accounted for by the regression model.**
#
# This shows that their is a reasonably strong relationship between total bill and tip amount but that other factors may also play their part in determining tip amount etc.

# %% [markdown]
# #### **Section 2.3 References:**
# * Simple Linear Regression with NumPy - https://nbviewer.jupyter.org/github/ianmcloughlin/jupyter-teaching-notebooks/blob/master/simple-linear-regression.ipynb
# * Introduction to linear regression: http://onlinestatbook.com/2/regression/intro.html
# * Line of best fit: https://www.investopedia.com/terms/l/line-of-best-fit.asp
# * Simple Linear Regression - Finding the equation of the line of best fit: http://www.ams.sunysb.edu/~zhu/ams571/Regression.pdf
# * numpy.mean: https://docs.scipy.org/doc/numpy/reference/generated/numpy.mean.html
# * numpy.polyfit documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html.
# * matplotlib.pyplot documentation: https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html
# * matplotlib.pyplot.plot(): https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html
# * matplotlib.pyplot.legend: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.legend.html
# * matplotlib.pyplot.ylabel: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.ylabel.html
# * matplotlib.pyplot.xlabel: https://matplotlib.org/3.1.0/tutorials/introductory/pyplot.html
# * matplotlib.pyplot.show() https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.show.html
# * numpy.corrcoef: https://docs.scipy.org/doc/numpy/reference/generated/numpy.corrcoef.html
# * Correlation in Python: http://benalexkeen.com/correlation-in-python/

# %% [markdown]
# ### 2.4: Scikit learn to analyse the linear relationship between total bill and tip amount
#
# Scikit-learn is a machine learning library in Python built on top of NumPy, SciPy and matplotlib. Some of the uses of Scikit-learn include regression and Classification analysis.
#
# **Some useful links:**
# * scikit-learn: https://scikit-learn.org/stable/
# * Supervised learning: https://scikit-learn.org/stable/supervised_learning.html#supervised-learning
# * Model selection and evaluation: https://scikit-learn.org/stable/model_selection.html#model-selection
#
# Within the Scikitlearn library there is a Linear Regression model which is used to calculate linear regression using the Ordinary least squares (OLS) method.
# The documentation page is here: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.
#
# I will import the model and try to calculate the slope, y intercept and R Squared values for the best fit line of total bill anf tip amounts.

# %% [markdown]
# **1. Import Linear Regression from Scikit learn:**

# %%
from sklearn.linear_model import LinearRegression
# imported scikit learn.linear_model.LinearRegression: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# **2. Divide the data into "attributes" and "labels":**
#
# Attributes are the independent variables and labels are the dependent variables which we want to predict based on the values of the independent variables.

# %%
x = df['total_bill'].values.reshape(-1,1)
# x variable is set to total bill amount which is the independent variable in this case which will affect the dependent variable tip
y = df['tip'].values.reshape(-1,1)
# y value set equal to tip amount which is the dependent variable which we will try to predict

# %% [markdown]
# I had to reshape the data as I got the below error message:
#
# _"Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample"_

# %% [markdown]
# **3. Fit the data:**

# %%
model= LinearRegression()
# variable model is set equal to the linear regression class 
model.fit(x, y) 
# .fit command is used to fit the linear model
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.fit
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# **4. Return the intercept value for the best fit line:**

# %%
model.intercept_
# .intercept returns the y intercept value of the best fit line
# Out:
# array([0.92026961])

# %% [markdown]
# **5. Return the slope of the best fit line:**

# %%
model.coef_
# .coef returns the slope of the best fit line
# Out:
# array([[0.10502452]])

# %% [markdown]
# **6. Return the R Squared value:**

# %%
model.score(x, y)
# .score returns the R Squared value
# Out:
# 0.45661658635167657

# %% [markdown]
# The slope, they intercept value and the R squared coefficients are the same as what I got earlier with numpy.polyfit. So I can see 45.6% of the variability of tip amounts can be expalined by the change in bill amounts.

# %% [markdown]
# #### **Regression - main findings:**
# * The results of this regression analysis showed there is a relationship between total bill and tip amounts.
# * From numpy.polyfit and Scikit learn linear regression model:
#     * The slope of the best fit line was returned as: 0.10502452
#     * The y intercept of the best fit line was returned as: 0.92026961
# * From numpy.corrcoef and Scikit learn linear regression model the R-squared value was returned as: 0.45661658635167635 which I interpret to mean 45.6% of the data is accounted for by the regression model.
# * This shows that their is a relationship between total bill and tip amount but that other factors may also play their part in determining tip amount etc.

# %% [markdown]
# #### **Section 2.4 References:**
# * PYTHON MACHINE LEARNING EXAMPLE – LINEAR REGRESSION: https://devarea.com/python-machine-learning-example-linear-regression/#.XdZkSej7TIU
# * Ordinary least squares: https://scikit-learn.org/stable/modules/linear_model.html#ordinary-least-squares
# * scikit learn.linear_model.LinearRegression: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# * numpy.polyfit documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html
# * Beginner's guide to regression in Python with Scikit learn: https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f
# * How to run linear regression in python scikit learn: https://bigdata-madesimple.com/how-to-run-linear-regression-in-python-scikit-learn/
# * Linear Regression — Python Implementation: https://towardsdatascience.com/linear-regression-python-implementation-ae0d95348ac4
# * .fit: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.fit
# * .score: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score
# * Interpreting the Intercept in a Regression Model: https://www.theanalysisfactor.com/interpreting-the-intercept-in-a-regression-model/

# %% [markdown]
# ## Section 3 - Relationship between the variables in the Tips data set
#
# **In this section I will analyse the relationship between the variables in the data set.**

# %% [markdown]
# ### Section 3.1: Seaborn.pairplot
#
# The documentation for seaborn.pairplot is here: https://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# Pairplot is used to plot the relationship between variables in a data set. The pairplot function by default plots each variable on the y axis across a single row and the x axis across a single column.
# Pairplot can read in a data set from pandas df (data frame). The argument hue can be entered to add colour to the plot based on another variable in the data set.
#
# I read about seaborn.pairplot on the following blog post: https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166 and I found the below section interesting:
#
# _"I’m still amazed that one simple line of code gives us this entire plot! The pairs plot builds on two basic figures, the histogram and the scatter plot. The histogram on the diagonal allows us to see the distribution of a single variable while the scatter plots on the upper and lower triangles show the relationship (or lack thereof) between two variables."_
#
# From: https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %%
sns.pairplot(df)
# Seaborn is able to read the dataframe (df) from pandas
# seaborn.pairplot by default plots a histogram when the hue argument is not used
# The user could enter an argument to change the type of plot

# %% [markdown]
# **Looking at the above pairplot:**
# * The plot on middle of the first row shows the relationship between total bill and tip amount and it is clear that the higher thr bill amount the higher thr tip amount tends to be.
# * Party size doesnt seem to have any clear influence on tip amount looking at the plot.
# * This plot is a useful overview of the relationship between total bill, tip amount and party size but doesnt go into too much detail in analysing the relationships.

# %% [markdown]
# #### Seaborn.pairplot - "diag_kind"
# **By default a histogram is plotted with seaborn.pairplot, this can be changes by adding the argument diag_kind:**
#
# The documentation page states:
#
# _"diag_kind : {‘auto’, ‘hist’, ‘kde’}, optional_
# _Kind of plot for the diagonal subplots. The default depends on whether "hue" is used or not."_
#
# From: https://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# The arguments are:
# * hist - histogram
# * kde - desnity plot
# * auto - if hue is used the default is density plot, if hue is not used the default is a histogram

# %%
sns.pairplot(df, diag_kind = 'kde')
# the argument diag_kind is used to change the type of plot to a density plot
# if the argument hue was used the default plot would be density plot
# when the argument hue is not used then the default plot in seaborn pairplot is a histogram
# Out:
# C:\Users\John\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Seaborn.pairplot - "hue"
# **seaborn.pairplot takes an argument 'hue' which adds colour to the pairplot based on a variable in the data set**
#
# The documentation page states:
#
# _"hue : string (variable name), optional
# Variable in data to map plot aspects to different colors."_
#
# From: https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(df, hue = 'day')
# seaborn.pairplot reads the pandas dataframe
# I have asked for the variable 'day' to be used to add colour to the pairplots

# %% [markdown]
# **Looking at the pairplot when broken out by day:**
# * The highest tip amount was given on Saturday, however this was also for the highest bill amount so I dont think this tells us much.
# * The party size again doesnt seem to exert too muxh influence over the bill amount as there is a fairly even distribution of tip amounts across all party sizes recorded.
# * I would expect a higher party size to yield a higher total bill amount and in turn a higher tip amount.

# %% [markdown]
# **By default when the "hue" argument is used a density plot is plotted with seaborn.pairplot, this can be changed by adding the argument diag_kind:**

# %%
sns.pairplot(df, hue= 'day', diag_kind = 'hist')
# I have added the argument diag_kind hist to plot histograms as I have used the hue argument

# sns.pairplot(df, hue= 'day', diag_kind = 'auto')
# The above line of code would display a density plot asI have used the hue argument

# %% [markdown]
# #### Section 3.1 References
# * The documentation for seaborn.pairplot is here: https://seaborn.pydata.org/generated/seaborn.pairplot.html
# * I read about seaborn.pairplot on the following blog post: https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166
# * Seaborn pairplot: https://pythonbasics.org/seaborn_pairplot/

# %% [markdown]
# ### Section 3.2 Seaborn.catplot
#
# Seaborn.catplot documentation: https://seaborn.pydata.org/generated/seaborn.catplot.html
#
# _"This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations._"
#
# With seaborn.catplot there are multiple different types of plots that can be used to show the relationships between numberic and categorical values.

# %% [markdown]
# **Swarmplot(): https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot**

# %% [markdown]
# **Relationship between bill amount, day and smoker:**

# %%
sns.catplot(x= 'day', y='total_bill', hue='smoker',kind='swarm', data=tips)

# %% [markdown]
# **Relationship between tip amount, day and smoker:**

# %%
sns.catplot(x= 'day', y='tip', hue='smoker',kind='swarm', data=tips)

# %% [markdown]
# **Findings:**
# * The shape of the catplots loooking at both bill and tip amounts look quite similar.
# * This leads me to believe there is some relationship between the size of the bill and the amount of tip given.
# * I do not think overall smoker has a huge impact on the size of the bill and tip.

# %% [markdown]
# #### Section 3.2 References
# * Seaborn.catplot documentation: https://seaborn.pydata.org/generated/seaborn.catplot.html
# * Swarmplot(): https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot

# %% [markdown]
# ### Section 3.3: pandas and seaborn to analyse relationship between variables in the data set
#
# **I am going to use pandas to analyse the relationship between some of the variables in the Tips data set and Seaborn to plot some different views of the relationship between these variables.**

# %% [markdown]
# ##### **The pandas functions I will use are:**
#
# ##### **Dataframe.groupby.mean() - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.mean.html**
#
# Dataframe.groupby.mean() could be used to return the mean values grouped by variable such as smoker and sex.
#
# ##### **Dataframe.groupby.sum() - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.sum.html**
# Dataframe.groupby.sum() would be used to return the sum total grouped by variable.
#
# I will use various types of Seaborn plots to show the results.

# %% [markdown]
# ### **Is there a relationship between Smoker and total bill and tip amount?:**

# %%
df.groupby('smoker').mean().round(2)
# dataframe.round: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.round.html
# Out:
#         total_bill   tip  size
# smoker
# No           19.19  2.99  2.67
# Yes          20.76  3.01  2.41

# %%
df.groupby('smoker').sum().round(2)
# Out:
#         total_bill     tip  size
# smoker
# No         2897.43  451.77   403
# Yes        1930.34  279.81   224

# %% [markdown]
# **Plot of total bill and tip amounts by party size broken into smoker and non smoker:**
#
# col and col_wrap are 2 parameters that can be entered in seaborn.relplot:
# * col - name of a variable in the data set that can be plotted broken out into columns on the plot
# * col_wrap - used to define how many columns of daa should appear in each row of the plot

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="size", col_wrap=3, data=tips)
# I used col parameter to plot by party size on the columns of the relplot
# I have used col_wrap to have 3 columns of plots per row on this plot

# %% [markdown]
# **Linear relationship between total bill and tip amount by smoker/non smoker:**

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %% [markdown]
# **Findings**
# * The mean bill is slighty higher for smoker and the tip amount is also slightly higher.
# * The mean party size is higher for smoker also.
# * However, over the course of the 4 days non smoker accounted for higher bill and tip revenue.
# * The most frequently occurring party size for both smoker and non smoker is 2 people.
# * I conclude here that smoker/non smoker doesnt have a direct relationship with tip revenue but we could expect more people to seat in the non smoking section which will in turn generate higher tip revenue.
# * A waiter/waitress looking at this may prefer to work in the non smoking section.

# %% [markdown]
# ### **Is there a relationship between Sex and total bill and tip amount?:**

# %%
df.groupby('sex').mean().round(2)
# round(2) used to round the output to 2 decimal places
# Out:
#         total_bill   tip  size
# sex
# Female       18.06  2.83  2.46
# Male         20.74  3.09  2.63

# %%
df.groupby('sex').sum().round(2)
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %% [markdown]
# **Seaborn.barplot(): https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot**
#
# _"A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars."_
#
# Source: https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot
#
# A barplot is useful if we want to plot the central tendency of data from a data set. The error bars shows us the margain for error in the central tendency shown in the barplot.

# %% [markdown]
# **Barplot showing the central tendency of tip values by sex:**

# %%
sns.barplot(x="tip", y="sex", data=tips)
# standard barplot showing tip by sex

# %% [markdown]
# **Findings:**
# * The mean bill and tip amounts are larger for male.
# * The mean size is also slightly larger for male.
# * Over the 4 days the revenue generated for bills paid by male was much higher than female.
# * The tip amount was also much higher for male.
# * I can see from the above barplot the central tendency of tips by male is slightly higher than female.

# %% [markdown]
# **Adding hue to show party size by color:**

# %%
sns.barplot(x="sex", y="tip", hue= "size", data=tips)
# hue parameter added to show party size broken out by color

# %% [markdown]
# There is a variation in the central tendency of tips when broken out by party size.

# %% [markdown]
# **Seaborn.catplot() could be used to plot a barplot which takes the "col" argument to plot some variable on columns:**

# %%
sns.catplot(x="sex", y="tip", hue= "size", col="time", kind="bar", data=tips)
# You can add col argument when useing catplot with kind bar instead of barplot
# Further reasding and exmaple shown here: https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot

# %% [markdown]
# ### **Is there a relationship between Day and total bill and tip amount?:**

# %%
df.groupby('day').mean().round(2)
# Out:
#       total_bill   tip  size
# day
# Fri        17.15  2.73  2.11
# Sat        20.44  2.99  2.52
# Sun        21.41  3.26  2.84
# Thur       17.68  2.77  2.45

# %%
df.groupby('day').sum().round(2)
# Out:
#       total_bill     tip  size
# day
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
# Thur     1096.33  171.83   152

# %% [markdown]
# Seaborn.boxplot(): https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
#
# Seaborn.swarmplot(): https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot
#
# **Boxplot of relationship between day and tip amount:**

# %%
sns.boxplot(x="day", y="tip", data=tips)

# %% [markdown]
# **Swarmplot of relationship between day and tip amount:**

# %%
sns.swarmplot(x="day", y="tip", data=tips)

# %% [markdown]
# **Boxplot of relationship between day and total bill amount:**

# %%
sns.boxplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# **Swarmplot of relationship between day and total bill amount:**

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# **Boxplot and Swarmplot combined:**

# %%
box = sns.boxplot(x="day", y="total_bill", data=tips)
swarm = sns.swarmplot(x="day", y="total_bill", data=tips, color=".2")
# I saw an exmaple of this in the seaborn.boxplot documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
# I sourced the parameter- color=".2" from an example here: https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot

# %% [markdown]
# ##### **Seaborn.stripplot()**
#
# Seaborn.stripplot() documentation: https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot**
#
# Seaborn.stripplot() is used to draw a scatterplot when one variable is categorical.
#
# **Stripplot of relationship between day and tip amount:**

# %%
sns.stripplot(x="tip", y="day", data=tips, linewidth=2)
# linewidth argument can be used to set the width of the boundary lines on the points on the scatterplot

# %% [markdown]
# **Linear relationship between total bill and tip amount broken out by day:**

# %%
sns.lmplot(x="total_bill", y="tip", hue="day", col="day", data=tips)
# col argument used to plot across 4 columns
# hue argument used to plot different colours

# %% [markdown]
# **Findings:**
# * I can see the day with the largest mean party size is Sunday with the smallest mean party size on Friday.
# * The largest mean bill amount is on Sunday with the smallest mean bill amount on Friday.
# * The day with the largest mean tip amount is also Sunday and the smallest tip amount is also Friday.
# * This would suggest to me there is a relationship between total bill amount and tip amount.
# * The highest bill and tip revenue and most amount of customers in the restaurant are recorded on Saturday.
# * The lowest bill and tip revenue and least amount of customers was recorded on Friday.
#
# **Looking at the linear relationship between total bill and tip amount broken out by day:**
# * As we saw earlier in our analyses Saturday and Sunday were the busiest days in the restaurant.
# * Looking here I see the highest tip amount was given on Saturday.
# * This tip amount was given on the highest bill amount.
# * However I also see the highest tips given on Thursday and Sunday were not given on the highest bill amounts.
# * I conclude that day has an impact on tip amounts, as there are more parties likely to dine in the restaurant on Saturday and Sunday and thus more tip revenue should be generated.

# %% [markdown]
# ### **Is there a relationship between Time and total bill and tip amount?:**

# %%
df.groupby('time').mean().round(2)
# Out:
#         total_bill   tip  size
# time
# Dinner       20.80  3.10  2.63
# Lunch        17.17  2.73  2.41

# %%
df.groupby('time').sum().round(2)
# Out:
#         total_bill     tip  size
# time
# Dinner     3660.30  546.07   463
# Lunch      1167.47  185.51   164

# %% [markdown]
# ##### **Seaborn.violinplot()**
#
# Seaborn.violinplot documentation: https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot
#
# Seborn.violinplot draws a combination of a boxplot and kernel density estimate.
#
# **Violinplot of relationship between time and tip amount:**

# %%
sns.violinplot(x="time", y="total_bill", data=tips)
# violinplot of total bill and time from the Tips data set

# %% [markdown]
# **Seaborn.violinplot takes the "hue" parameter to show a third variable on the plot:**

# %%
sns.violinplot(x="time", y="total_bill", hue="day", data=tips)
# hue paramter added to show day by color on the plot

# %% [markdown]
# **Seaborn.catplot with kind="violin" takes the parameter "col" to add columns to the plot:**

# %%
sns.catplot(x="time", y="total_bill", col="day", kind="violin", data=tips)
# seaborn.catplot with kind="violin" takes the "col" parameter
# the "col" parameter plots a column for each occurrence of the variable it is called for.

# %% [markdown]
# **Seaborn.lmplot linear relationship between day, time and total bill amount:**

# %%
sns.lmplot(x="total_bill", y="tip", hue="time", col="day", data=tips, col_wrap=2)
# col argument used to plot across 4 columns
# hue argument used to plot different colours

# %% [markdown]
# **Findings:**
# * Dinner yields much higher bill and tip revenue than lunch.
# * It must be noted dinner entries are recorded for 4 days and lunch for 2 days in the data set.
# * The mean bill, tip and party size are greater at dinner time than at lunch time.
# * Looking at this, a waiter may prefer to work at dinner time that at lunch time.

# %% [markdown]
# ### **Day and time combined:**

# %%
df.groupby(['day','time']).mean().round(2)
# Out:
#              total_bill   tip  size
# day  time
# Fri  Dinner       19.66  2.94  2.17
#      Lunch        12.85  2.38  2.00
# Sat  Dinner       20.44  2.99  2.52
# Sun  Dinner       21.41  3.26  2.84
# Thur Dinner       18.78  3.00  2.00
#      Lunch        17.66  2.77  2.46

# %%
df.groupby(['day','time']).sum().round(2)
# Out:
#              total_bill     tip  size
# day  time
# Fri  Dinner      235.96   35.28    26
#      Lunch        89.92   16.68    14
# Sat  Dinner     1778.40  260.40   219
# Sun  Dinner     1627.16  247.39   216
# Thur Dinner       18.78    3.00     2
#      Lunch      1077.55  168.83   150

# %% [markdown]
# **Boxplot of relationship between day, time and tip amount:**

# %%
sns.boxplot(x="day", y="tip", hue="time", data=tips, linewidth=3)
# linewidth parametr can be added to incraese width of the lines in the boxplot

# %% [markdown]
# **Stripplot of relationship between day, time and tip amount:**

# %%
sns.stripplot(x="tip", y="day",hue="time", data=tips, linewidth=1)

# %% [markdown]
# **Stripplot of relationship between day, time and total bill:**

# %%
sns.stripplot(x="total_bill", y="day",hue="time", data=tips, linewidth=1)

# %% [markdown]
# **Seaborn.catplot with kind="strip" takes the "col" argument whch plots each occurrence of the specified variable as a column on the plot:**

# %%
sns.catplot(x="tip", y="day",col="time", data=tips, kind="strip")

# %% [markdown]
# **Boxplot and Stripplot combined:**

# %%
box = sns.boxplot(x="day", y="tip", hue="time", data=tips, linewidth=3)
strip = sns.stripplot(x="day", y="tip",hue="time", data=tips, linewidth=1)
# when i give the names box and strip they will both be plotted together
# I read an exmaple here: https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot

# %% [markdown]
# **Findings:**
# * The highest mean tip amount is Sunday at dinner time.
# * The lowest mean tip amount is Friday at lunch time.
# * The highest mean tip is recorded against the highest mean party size and highest mean bill amount.
# * The lowest mean tip is recorded against the lowest mean bill amount and the lowest mean party size.
# * This suggests me to party size and bill amount have an effect on tip amount.
# * The restaurant appears to only open for lunch on Thursday and Friday.
# * Dinner on Thursday was extremely quiet with only 2 customers.
# * There were 219 customers for dinner on Saturday and 216 for dinner on Sunday.
# * Interestingly lunch time on Thursday was quiet busy compared with dinner time on Thursday whereas the opposite was the case on Friday with dinner being busier than lunch.
# * These statistics could be used by the restaurant to predict their busy and quiet times and plan accordingly.

# %% [markdown]
# #### Section 3.3 References
# * pandas sum: https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# * Dataframe.sum(): https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html
# * pandas.groupby in action: https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
# * Blog post: https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
# * Dataframe.round(): https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.round.html
# * Dataframe.groupby.mean() - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.mean.html
# * Dataframe.groupby.sum() - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.sum.html
# * Seaborn.swarmplot(): https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot
# * Seaborn.boxplot(): https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
# * Seaborn.stripplot(): https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot
# * Seaborn.violinplot documentation: https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot
# * Blog post: https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e

# %% [markdown]
# ## Section 4 - Conclusion

# %% [markdown]
# * In completing this project I first researched some background information on the Tips data set and read some blog posts of analysis some people had completed analysing the Tips data set.
# * I then downloaded the Tips data set and did some decsriptive analysis using pandas.
# * I used Seaborn to visualise the data set with some plots.
# * This gave me a better understanding of some of the properties of the data set.
# * I used regression analysis to examine if there was a relationship between bill and tip amounts.
# * In order to do this I had to research what regression analysis is and how to go about doing it.
# * I learnt that Seaborn, NumPy and scikit-learn can all be used in regression analysis and I used all of the packages in conducting my regression analysis. This involved using learnings from the series of lecture videos on regression and also additional research.
# * In the final section of my project I undertook an analysis in order to identify if there was any relationship between some lof the variables in the data set.
# * I used Seaborn.pairplot and Seaborn.catplot to plot the relationship between some of the variables.
# * I also used the pandas.groupby function to group by variable and analyse the mean and sum of bill and tip by variable. I used severeal different type of plots to visualise these relationships.
# * In the end I feel I am coming away this project with a better understanding of the Seaborn package, regression analysis and I have developed some data analysis skills which I hope to use in future projects and in the workplace.

# %% [markdown]
# ## End
